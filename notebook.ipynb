# %%
from plot_utils import collect_lightning_logs

# %%
import pandas as pd

# Set pandas display options to show all rows and columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

df = collect_lightning_logs()

to_hide = ['final_epoch', 'best_valid_acc']
groups = df.groupby(["dataset", "strategy"])
# print("Groups:", list(groups.groups.keys()))

for name, group in groups:
    # drop unwanted columns before displaying (do not modify original df)
    group_to_show = group.drop(columns=[c for c in to_hide if c in group.columns])
    print(f"\n== {name} ({len(group)} rows) ==")
    display(group_to_show)
# Out:
# == ('aclcifar10', 'FWD') (1 rows) ==
#          version     dataset strategy strategy_type transition_matrix  \
# 240  version_379  aclcifar10      FWD           TGA           uniform
#
#      best_test_acc  seed     model   augment
# 240      58.721274    42  ResNet34  flipflop
# == ('aclcifar20', 'FWD') (1 rows) ==
#          version     dataset strategy strategy_type transition_matrix  \
# 241  version_380  aclcifar20      FWD           TGA           uniform
#
#      best_test_acc  seed     model   augment
# 241      26.829621    42  ResNet34  flipflop
# == ('cifar10', 'CE') (3 rows) ==
#          version  dataset strategy strategy_type transition_matrix  \
# 219  version_356  cifar10       CE            NL        llava_true
# 220  version_357  cifar10       CE            NL        llava_true
# 221  version_358  cifar10       CE            NL        llava_true
#
#      best_test_acc  seed     model augment
# 219      84.688646    42  ResNet34    None
# 220      85.106277  1126  ResNet34    None
# 221      85.473347  2202  ResNet34    None
# == ('cifar10', 'CPE') (38 rows) ==
#          version  dataset strategy strategy_type           transition_matrix  \
# 7    version_108  cifar10      CPE             F      llava_kmean=10_nrand=4
# 65   version_179  cifar10      CPE             F      llava_kmean=10_nrand=4
# 67   version_180  cifar10      CPE             F      llava_kmean=10_nrand=4
# 68   version_181  cifar10      CPE             F      llava_kmean=10_nrand=4
# 69   version_182  cifar10      CPE             I      llava_kmean=10_nrand=4
# 70   version_183  cifar10      CPE             I      llava_kmean=10_nrand=4
# 71   version_184  cifar10      CPE             I      llava_kmean=10_nrand=4
# 72   version_185  cifar10      CPE             T      llava_kmean=10_nrand=4
# 73   version_186  cifar10      CPE             T      llava_kmean=10_nrand=4
# 74   version_187  cifar10      CPE             T      llava_kmean=10_nrand=4
# 110  version_234  cifar10      CPE             F      llava_kmean=10_nrand=4
# 111  version_235  cifar10      CPE             F      llava_kmean=10_nrand=4
# 112  version_236  cifar10      CPE             F      llava_kmean=10_nrand=4
# 113  version_237  cifar10      CPE             I      llava_kmean=10_nrand=4
# 114  version_238  cifar10      CPE             I      llava_kmean=10_nrand=4
# 115  version_239  cifar10      CPE             I      llava_kmean=10_nrand=4
# 117  version_240  cifar10      CPE             T      llava_kmean=10_nrand=4
# 118  version_241  cifar10      CPE             T      llava_kmean=10_nrand=4
# 119  version_242  cifar10      CPE             T      llava_kmean=10_nrand=4
# 288  version_434  cifar10      CPE             F   llava_noise=False-nrand=2
# 289  version_435  cifar10      CPE             F   llava_noise=False-nrand=3
# 291  version_437  cifar10      CPE             F   llava_noise=False-nrand=4
# 305  version_450  cifar10      CPE             F   llava_noise=False-nrand=5
# 306  version_451  cifar10      CPE             F   llava_noise=False-nrand=6
# 308  version_453  cifar10      CPE             F   llava_noise=False-nrand=7
# 318  version_462  cifar10      CPE             F   llava_noise=False-nrand=8
# 319  version_463  cifar10      CPE             F   llava_noise=False-nrand=9
# 321  version_465  cifar10      CPE             F  llava_noise=False-nrand=10
# 372  version_538  cifar10      CPE             F      llava_kmean=10_nrand=4
# 373  version_539  cifar10      CPE             F      llava_kmean=10_nrand=4
# 375  version_540  cifar10      CPE             F      llava_kmean=10_nrand=4
# 378   version_57  cifar10      CPE             F                   as_setup1
# 382   version_60  cifar10      CPE             F                   as_setup2
# 383   version_61  cifar10      CPE             F                   as_setup3
# 384   version_64  cifar10      CPE             F                   as_setup4
# 403   version_88  cifar10      CPE             T                   as_setup3
# 404   version_89  cifar10      CPE             T                   as_setup3
# 406   version_90  cifar10      CPE             T                   as_setup3
#
#      best_test_acc  seed     model   augment
# 7        10.086167    42  ResNet18      None
# 65       77.607995    42  ResNet18      None
# 67       78.575945  1126  ResNet18      None
# 68       78.887290  2202  ResNet18      None
# 69       75.228631    42  ResNet18      None
# 70       76.322383  1126  ResNet18      None
# 71       75.379133  2202  ResNet18      None
# 72       76.001263    42  ResNet18      None
# 73       78.322041  1126  ResNet18      None
# 74       78.077900  2202  ResNet18      None
# 110      77.884883    42  ResNet34      None
# 111      78.033662  1126  ResNet34      None
# 112      78.694278  2202  ResNet34      None
# 113      76.240808    42  ResNet34      None
# 114      75.535387  1126  ResNet34      None
# 115      76.851451  2202  ResNet34      None
# 117      70.805949    42  ResNet34      None
# 118      77.886027  1126  ResNet34      None
# 119      65.323418  2202  ResNet34      None
# 288      84.090072    42  ResNet18  flipflop
# 289      82.779181    42  ResNet18  flipflop
# 291      83.890742    42  ResNet18  flipflop
# 305      83.672446    42  ResNet18  flipflop
# 306      80.799055    42  ResNet18  flipflop
# 308      73.505288    42  ResNet18  flipflop
# 318      71.964616    42  ResNet18  flipflop
# 319      62.554574    42  ResNet18  flipflop
# 321      63.138217    42  ResNet18  flipflop
# 372      78.188765    42  ResNet50  flipflop
# 373      78.077900  1126  ResNet50  flipflop
# 375      77.440834  2202  ResNet50  flipflop
# 378       0.861788    42  ResNet18      None
# 382       0.844514    42  ResNet18      None
# 383       0.845588    42  ResNet18      None
# 384       0.874236    42  ResNet18      None
# 403      83.959103    42  ResNet18      None
# 404      84.445089  1126  ResNet18      None
# 406      85.478514  2202  ResNet18      None
# == ('cifar10', 'FWD') (26 rows) ==
#          version  dataset strategy strategy_type           transition_matrix  \
# 20   version_138  cifar10      FWD            NL      llava_kmean=10_nrand=4
# 23   version_140  cifar10      FWD            NL      llava_kmean=10_nrand=4
# 25   version_142  cifar10      FWD            NL      llava_kmean=10_nrand=4
# 28   version_145  cifar10      FWD            NL      llava_kmean=10_nrand=4
# 100  version_225  cifar10      FWD            NL      llava_kmean=10_nrand=4
# 101  version_226  cifar10      FWD            NL      llava_kmean=10_nrand=4
# 102  version_227  cifar10      FWD            NL      llava_kmean=10_nrand=4
# 242  version_381  cifar10      FWD           TGA                     uniform
# 255  version_394  cifar10      FWD           TGA      llava_kmean=10_nrand=4
# 256  version_395  cifar10      FWD           TGA      llava_kmean=10_nrand=4
# 257  version_396  cifar10      FWD            NL   llava_noise=False-nrand=2
# 258  version_397  cifar10      FWD            NL   llava_noise=False-nrand=3
# 259  version_398  cifar10      FWD            NL   llava_noise=False-nrand=4
# 264  version_402  cifar10      FWD            NL   llava_noise=False-nrand=5
# 265  version_403  cifar10      FWD            NL   llava_noise=False-nrand=6
# 266  version_404  cifar10      FWD            NL   llava_noise=False-nrand=7
# 270  version_408  cifar10      FWD            NL   llava_noise=False-nrand=8
# 271  version_409  cifar10      FWD            NL   llava_noise=False-nrand=9
# 283  version_423  cifar10      FWD            NL  llava_noise=False-nrand=10
# 333   version_49  cifar10      FWD            NL                   as_setup1
# 352   version_52  cifar10      FWD            NL                   as_setup2
# 369  version_535  cifar10      FWD            NL      llava_kmean=10_nrand=4
# 370  version_536  cifar10      FWD            NL      llava_kmean=10_nrand=4
# 371  version_537  cifar10      FWD            NL      llava_kmean=10_nrand=4
# 376   version_55  cifar10      FWD            NL                   as_setup3
# 385   version_65  cifar10      FWD             F                   as_setup4
#
#      best_test_acc  seed     model   augment
# 20       77.753907    42  ResNet18      None
# 23       77.753907    42  ResNet18      None
# 25       79.180259  1126  ResNet18      None
# 28       79.433024  2202  ResNet18      None
# 100      78.204852    42  ResNet34      None
# 101      78.543776  1126  ResNet34      None
# 102      79.081458  2202  ResNet34      None
# 242      67.024934    42  ResNet34  flipflop
# 255      78.204852    42  ResNet34  flipflop
# 256      78.443819    42  ResNet34  flipflop
# 257      84.916705    42  ResNet18  flipflop
# 258      83.993572    42  ResNet18  flipflop
# 259      84.082031    42  ResNet18  flipflop
# 264      84.268153    42  ResNet18  flipflop
# 265      80.463582    42  ResNet18  flipflop
# 266      73.644304    42  ResNet18  flipflop
# 270      71.994489    42  ResNet18  flipflop
# 271      63.081342    42  ResNet18  flipflop
# 283      62.871665    42  ResNet18  flipflop
# 333       0.862374    42  ResNet18      None
# 352       0.846846    42  ResNet18      None
# 369      78.489202    42  ResNet50  flipflop
# 370      78.645450  1126  ResNet50  flipflop
# 371      78.244489  2202  ResNet50  flipflop
# 376       0.849288    42  ResNet18      None
# 385       0.873943    42  ResNet18      None
# == ('cifar10', 'URE') (12 rows) ==
#          version  dataset strategy strategy_type       transition_matrix  \
# 29   version_146  cifar10      URE           TNN  llava_kmean=10_nrand=4
# 30   version_147  cifar10      URE           TNN  llava_kmean=10_nrand=4
# 31   version_148  cifar10      URE           TNN  llava_kmean=10_nrand=4
# 32   version_149  cifar10      URE           TGA  llava_kmean=10_nrand=4
# 34   version_150  cifar10      URE           TGA  llava_kmean=10_nrand=4
# 35   version_151  cifar10      URE           TGA  llava_kmean=10_nrand=4
# 103  version_228  cifar10      URE           TNN  llava_kmean=10_nrand=4
# 104  version_229  cifar10      URE           TNN  llava_kmean=10_nrand=4
# 106  version_230  cifar10      URE           TNN  llava_kmean=10_nrand=4
# 107  version_231  cifar10      URE           TGA  llava_kmean=10_nrand=4
# 108  version_232  cifar10      URE           TGA  llava_kmean=10_nrand=4
# 109  version_233  cifar10      URE           TGA  llava_kmean=10_nrand=4
#
#      best_test_acc  seed     model augment
# 29       40.560088    42  ResNet18    None
# 30       42.871094  1126  ResNet18    None
# 31       45.097086  2202  ResNet18    None
# 32       10.058594    42  ResNet18    None
# 34       40.895566  1126  ResNet18    None
# 35       50.399244  2202  ResNet18    None
# 103      40.665212    42  ResNet34    None
# 104      37.330538  1126  ResNet34    None
# 106      37.769419  2202  ResNet34    None
# 107      10.058594    42  ResNet34    None
# 108      26.052389  1126  ResNet34    None
# 109      41.104665  2202  ResNet34    None
# == ('cifar100', 'CE') (3 rows) ==
#          version   dataset strategy strategy_type transition_matrix  \
# 225  version_363  cifar100       CE            NL        llava_true
# 226  version_364  cifar100       CE            NL        llava_true
# 227  version_365  cifar100       CE            NL        llava_true
#
#      best_test_acc  seed     model augment
# 225      36.881319    42  ResNet34    None
# 226      35.939226  1126  ResNet34    None
# 227      36.656138  2202  ResNet34    None
# == ('cifar100', 'CPE') (54 rows) ==
#          version   dataset strategy strategy_type           transition_matrix  \
# 2    version_101  cifar100      CPE             T                     uniform
# 3    version_102  cifar100      CPE             T                     uniform
# 46   version_161  cifar100      CPE             F     llava_kmean=100_nrand=4
# 47   version_162  cifar100      CPE             F     llava_kmean=100_nrand=4
# 48   version_163  cifar100      CPE             F     llava_kmean=100_nrand=4
# 49   version_164  cifar100      CPE             I     llava_kmean=100_nrand=4
# 50   version_165  cifar100      CPE             I     llava_kmean=100_nrand=4
# 51   version_166  cifar100      CPE             I     llava_kmean=100_nrand=4
# 52   version_167  cifar100      CPE             T     llava_kmean=100_nrand=4
# 53   version_168  cifar100      CPE             T     llava_kmean=100_nrand=4
# 54   version_169  cifar100      CPE             T     llava_kmean=100_nrand=4
# 130   version_26  cifar100      CPE             F                     uniform
# 134   version_27  cifar100      CPE             I                     uniform
# 144   version_28  cifar100      CPE             I                     uniform
# 150   version_29  cifar100      CPE             F                     uniform
# 158  version_297  cifar100      CPE             F     llava_kmean=100_nrand=4
# 159  version_298  cifar100      CPE             F     llava_kmean=100_nrand=4
# 160  version_299  cifar100      CPE             F     llava_kmean=100_nrand=4
# 161   version_30  cifar100      CPE             I                     uniform
# 162  version_300  cifar100      CPE             I     llava_kmean=100_nrand=4
# 163  version_301  cifar100      CPE             I     llava_kmean=100_nrand=4
# 164  version_302  cifar100      CPE             I     llava_kmean=100_nrand=4
# 165  version_303  cifar100      CPE             T     llava_kmean=100_nrand=4
# 166  version_304  cifar100      CPE             T     llava_kmean=100_nrand=4
# 167  version_305  cifar100      CPE             T     llava_kmean=100_nrand=4
# 172   version_31  cifar100      CPE             F                     uniform
# 198  version_333  cifar100      CPE             F                     uniform
# 199  version_334  cifar100      CPE             F                     uniform
# 200  version_335  cifar100      CPE             F                     uniform
# 201  version_336  cifar100      CPE             I                     uniform
# 202  version_337  cifar100      CPE             I                     uniform
# 203  version_338  cifar100      CPE             I                     uniform
# 204  version_339  cifar100      CPE             T                     uniform
# 205  version_340  cifar100      CPE             T                     uniform
# 206  version_341  cifar100      CPE             T                     uniform
# 293  version_439  cifar100      CPE             F   llava_noise=False-nrand=2
# 294  version_440  cifar100      CPE             F   llava_noise=False-nrand=3
# 296  version_442  cifar100      CPE             F   llava_noise=False-nrand=4
# 300  version_446  cifar100      CPE             F   llava_noise=False-nrand=5
# 301  version_447  cifar100      CPE             F   llava_noise=False-nrand=6
# 302  version_448  cifar100      CPE             F   llava_noise=False-nrand=7
# 310  version_455  cifar100      CPE             F   llava_noise=False-nrand=8
# 311  version_456  cifar100      CPE             F   llava_noise=False-nrand=9
# 312  version_457  cifar100      CPE             F  llava_noise=False-nrand=10
# 342  version_510  cifar100      CPE             F                     uniform
# 343  version_511  cifar100      CPE             F                     uniform
# 344  version_512  cifar100      CPE             F                     uniform
# 366  version_532  cifar100      CPE             F     llava_kmean=100_nrand=4
# 367  version_533  cifar100      CPE             F     llava_kmean=100_nrand=4
# 368  version_534  cifar100      CPE             F     llava_kmean=100_nrand=4
# 400   version_85  cifar100      CPE             T                   as_setup3
# 401   version_86  cifar100      CPE             T                   as_setup3
# 402   version_87  cifar100      CPE             T                   as_setup3
# 412   version_99  cifar100      CPE             T                     uniform
#
#      best_test_acc  seed     model   augment
# 2         4.574908  1126  ResNet18      None
# 3         2.645910  2202  ResNet18      None
# 46       43.978629  1126  ResNet18      None
# 47       43.677622    42  ResNet18      None
# 48       45.434284  2202  ResNet18      None
# 49       34.167048    42  ResNet18      None
# 50       33.876380  1126  ResNet18      None
# 51       34.042969  2202  ResNet18      None
# 52       44.615123    42  ResNet18      None
# 53       43.980929  1126  ResNet18      None
# 54       44.439340  2202  ResNet18      None
# 130       0.073403  1126  ResNet18      None
# 134       0.040631  2202  ResNet18      None
# 144       0.037310    42  ResNet18      None
# 150       0.051815    42  ResNet18      None
# 158      43.353057    42  ResNet34      None
# 159      44.880515  1126  ResNet34      None
# 160      44.640398  2202  ResNet34      None
# 161       0.041831  1126  ResNet18      None
# 162      34.738627    42  ResNet34      None
# 163      35.978863  1126  ResNet34      None
# 164      35.903034  2202  ResNet34      None
# 165      41.515970    42  ResNet34      None
# 166      45.676699  1126  ResNet34      None
# 167      44.336510  2202  ResNet34      None
# 172       0.051160  2202  ResNet18      None
# 198       5.792165    42  ResNet34      None
# 199       4.071691  1126  ResNet34      None
# 200       4.192900  2202  ResNet34      None
# 201       3.193934    42  ResNet34      None
# 202       3.675896  1126  ResNet34      None
# 203       3.369715  2202  ResNet34      None
# 204       2.759651    42  ResNet34      None
# 205       2.123162  1126  ResNet34      None
# 206       1.742302  2202  ResNet34      None
# 293      52.013445    42  ResNet18  flipflop
# 294      57.537913    42  ResNet18  flipflop
# 296      56.929576    42  ResNet18  flipflop
# 300      57.190371    42  ResNet18  flipflop
# 301      56.527460    42  ResNet18  flipflop
# 302      55.887526    42  ResNet18  flipflop
# 310      55.151653    42  ResNet18  flipflop
# 311      56.149477    42  ResNet18  flipflop
# 312      55.995524    42  ResNet18  flipflop
# 342       5.064913    42  ResNet50  flipflop
# 343       5.190143  1126  ResNet50  flipflop
# 344       4.157284  2202  ResNet50  flipflop
# 366      42.093292    42  ResNet50  flipflop
# 367      42.056528  1126  ResNet50  flipflop
# 368      40.607196  2202  ResNet50  flipflop
# 400      54.551929    42  ResNet18      None
# 401      56.617075  1126  ResNet18      None
# 402      52.641314  2202  ResNet18      None
# 412       4.499081    42  ResNet18      None
# == ('cifar100', 'FWD') (27 rows) ==
#          version   dataset strategy strategy_type           transition_matrix  \
# 8     version_11  cifar100      FWD            NL                     uniform
# 13    version_12  cifar100      FWD            NL                     uniform
# 14    version_13  cifar100      FWD            NL                     uniform
# 36   version_152  cifar100      FWD            NL     llava_kmean=100_nrand=4
# 37   version_153  cifar100      FWD            NL     llava_kmean=100_nrand=4
# 38   version_154  cifar100      FWD            NL     llava_kmean=100_nrand=4
# 135  version_271  cifar100      FWD            NL     llava_kmean=100_nrand=4
# 136  version_272  cifar100      FWD            NL     llava_kmean=100_nrand=4
# 137  version_273  cifar100      FWD            NL     llava_kmean=100_nrand=4
# 188  version_324  cifar100      FWD            NL                     uniform
# 189  version_325  cifar100      FWD            NL                     uniform
# 190  version_326  cifar100      FWD            NL                     uniform
# 274  version_414  cifar100      FWD            NL   llava_noise=False-nrand=2
# 275  version_415  cifar100      FWD            NL   llava_noise=False-nrand=4
# 276  version_416  cifar100      FWD            NL   llava_noise=False-nrand=5
# 277  version_417  cifar100      FWD            NL   llava_noise=False-nrand=6
# 278  version_418  cifar100      FWD            NL   llava_noise=False-nrand=7
# 279  version_419  cifar100      FWD            NL   llava_noise=False-nrand=8
# 280  version_420  cifar100      FWD            NL   llava_noise=False-nrand=9
# 281  version_421  cifar100      FWD            NL  llava_noise=False-nrand=10
# 286  version_426  cifar100      FWD            NL   llava_noise=False-nrand=3
# 339  version_507  cifar100      FWD            NL                     uniform
# 340  version_508  cifar100      FWD            NL                     uniform
# 341  version_509  cifar100      FWD            NL                     uniform
# 360  version_527  cifar100      FWD            NL     llava_kmean=100_nrand=4
# 364  version_530  cifar100      FWD            NL     llava_kmean=100_nrand=4
# 365  version_531  cifar100      FWD            NL     llava_kmean=100_nrand=4
#
#      best_test_acc  seed     model   augment
# 8         0.073392  1126  ResNet18      None
# 13        0.052792    42  ResNet18      None
# 14        0.054199  2202  ResNet18      None
# 36       44.299746  1126  ResNet18      None
# 37       44.191179    42  ResNet18      None
# 38       45.942098  2202  ResNet18      None
# 135      43.650046    42  ResNet34      None
# 136      45.183250  1126  ResNet34      None
# 137      44.961509  2202  ResNet34      None
# 188       5.794462    42  ResNet34      None
# 189       4.014247  1126  ResNet34      None
# 190       4.192900  2202  ResNet34      None
# 274      50.506085    42  ResNet18  flipflop
# 275      57.285160    42  ResNet18  flipflop
# 276      57.474154    42  ResNet18  flipflop
# 277      56.993914    42  ResNet18  flipflop
# 278      56.421763    42  ResNet18  flipflop
# 279      55.767465    42  ResNet18  flipflop
# 280      55.307907    42  ResNet18  flipflop
# 281      56.051821    42  ResNet18  flipflop
# 286      58.000916    42  ResNet18  flipflop
# 339       5.109720    42  ResNet50  flipflop
# 340       5.233226  1126  ResNet50  flipflop
# 341       4.107307  2202  ResNet50  flipflop
# 360      42.420149    42  ResNet50  flipflop
# 364      42.605695  1126  ResNet50  flipflop
# 365      41.102943  2202  ResNet50  flipflop
# == ('cifar100', 'URE') (24 rows) ==
#          version   dataset strategy strategy_type        transition_matrix  \
# 0     version_10  cifar100      URE           TNN                  uniform
# 22    version_14  cifar100      URE           TNN                  uniform
# 33    version_15  cifar100      URE           TGA                  uniform
# 39   version_155  cifar100      URE           TNN  llava_kmean=100_nrand=4
# 40   version_156  cifar100      URE           TNN  llava_kmean=100_nrand=4
# 41   version_157  cifar100      URE           TNN  llava_kmean=100_nrand=4
# 42   version_158  cifar100      URE           TGA  llava_kmean=100_nrand=4
# 43   version_159  cifar100      URE           TGA  llava_kmean=100_nrand=4
# 44    version_16  cifar100      URE           TNN                  uniform
# 45   version_160  cifar100      URE           TGA  llava_kmean=100_nrand=4
# 55    version_17  cifar100      URE           TGA                  uniform
# 66    version_18  cifar100      URE           TGA                  uniform
# 138  version_274  cifar100      URE           TNN  llava_kmean=100_nrand=4
# 139  version_275  cifar100      URE           TNN  llava_kmean=100_nrand=4
# 140  version_276  cifar100      URE           TNN  llava_kmean=100_nrand=4
# 141  version_277  cifar100      URE           TGA  llava_kmean=100_nrand=4
# 142  version_278  cifar100      URE           TGA  llava_kmean=100_nrand=4
# 143  version_279  cifar100      URE           TGA  llava_kmean=100_nrand=4
# 191  version_327  cifar100      URE           TNN                  uniform
# 192  version_328  cifar100      URE           TNN                  uniform
# 193  version_329  cifar100      URE           TNN                  uniform
# 195  version_330  cifar100      URE           TGA                  uniform
# 196  version_331  cifar100      URE           TGA                  uniform
# 197  version_332  cifar100      URE           TGA                  uniform
#
#      best_test_acc  seed     model augment
# 0         0.013258  2202  ResNet18    None
# 22        0.014223  1126  ResNet18    None
# 33        0.010110  1126  ResNet18    None
# 39       10.175207    42  ResNet18    None
# 40        8.357077  1126  ResNet18    None
# 41       10.218290  2202  ResNet18    None
# 42        1.002413    42  ResNet18    None
# 43        1.002413  1126  ResNet18    None
# 44        0.014126    42  ResNet18    None
# 45        1.019646  2202  ResNet18    None
# 55        0.010622    42  ResNet18    None
# 66        0.010185  2202  ResNet18    None
# 138       9.474380    42  ResNet34    None
# 139       8.156020  1126  ResNet34    None
# 140       9.640395  2202  ResNet34    None
# 141       1.002413    42  ResNet34    None
# 142       1.002413  1126  ResNet34    None
# 143       1.002413  2202  ResNet34    None
# 191       1.322381    42  ResNet34    None
# 192       1.264936  1126  ResNet34    None
# 193       1.207491  2202  ResNet34    None
# 195       1.003562    42  ResNet34    None
# 196       1.088006  1126  ResNet34    None
# 197       1.002413  2202  ResNet34    None
# == ('cifar20', 'CE') (3 rows) ==
#          version  dataset strategy strategy_type transition_matrix  \
# 222  version_359  cifar20       CE            NL        llava_true
# 223  version_360  cifar20       CE            NL        llava_true
# 224  version_361  cifar20       CE            NL        llava_true
#
#      best_test_acc  seed     model augment
# 222      33.127299    42  ResNet34    None
# 223      33.429459  1126  ResNet34    None
# 224      33.024472  2202  ResNet34    None
# == ('cifar20', 'CPE') (51 rows) ==
#          version  dataset strategy strategy_type           transition_matrix  \
# 1    version_100  cifar20      CPE             T                     uniform
# 9    version_110  cifar20      CPE             F      llava_kmean=20_nrand=4
# 56   version_170  cifar20      CPE             F      llava_kmean=20_nrand=4
# 57   version_171  cifar20      CPE             F      llava_kmean=20_nrand=4
# 58   version_172  cifar20      CPE             F      llava_kmean=20_nrand=4
# 59   version_173  cifar20      CPE             I      llava_kmean=20_nrand=4
# 60   version_174  cifar20      CPE             I      llava_kmean=20_nrand=4
# 61   version_175  cifar20      CPE             I      llava_kmean=20_nrand=4
# 62   version_176  cifar20      CPE             T      llava_kmean=20_nrand=4
# 63   version_177  cifar20      CPE             T      llava_kmean=20_nrand=4
# 64   version_178  cifar20      CPE             T      llava_kmean=20_nrand=4
# 79    version_20  cifar20      CPE             I                     uniform
# 83    version_21  cifar20      CPE             I                     uniform
# 94    version_22  cifar20      CPE             I                     uniform
# 105   version_23  cifar20      CPE             F                     uniform
# 116   version_24  cifar20      CPE             F                     uniform
# 125   version_25  cifar20      CPE             F                     uniform
# 148  version_288  cifar20      CPE             F      llava_kmean=20_nrand=4
# 149  version_289  cifar20      CPE             F      llava_kmean=20_nrand=4
# 151  version_290  cifar20      CPE             F      llava_kmean=20_nrand=4
# 152  version_291  cifar20      CPE             I      llava_kmean=20_nrand=4
# 153  version_292  cifar20      CPE             I      llava_kmean=20_nrand=4
# 154  version_293  cifar20      CPE             I      llava_kmean=20_nrand=4
# 155  version_294  cifar20      CPE             T      llava_kmean=20_nrand=4
# 156  version_295  cifar20      CPE             T      llava_kmean=20_nrand=4
# 157  version_296  cifar20      CPE             T      llava_kmean=20_nrand=4
# 290  version_436  cifar20      CPE             F   llava_noise=False-nrand=2
# 292  version_438  cifar20      CPE             F   llava_noise=False-nrand=3
# 295  version_441  cifar20      CPE             F   llava_noise=False-nrand=4
# 303  version_449  cifar20      CPE             F   llava_noise=False-nrand=5
# 307  version_452  cifar20      CPE             F   llava_noise=False-nrand=6
# 309  version_454  cifar20      CPE             F   llava_noise=False-nrand=7
# 317  version_461  cifar20      CPE             F   llava_noise=False-nrand=8
# 320  version_464  cifar20      CPE             F   llava_noise=False-nrand=9
# 322  version_466  cifar20      CPE             F  llava_noise=False-nrand=10
# 348  version_516  cifar20      CPE             F                     uniform
# 349  version_517  cifar20      CPE             F                     uniform
# 350  version_518  cifar20      CPE             F                     uniform
# 359  version_526  cifar20      CPE             F      llava_kmean=20_nrand=4
# 361  version_528  cifar20      CPE             F      llava_kmean=20_nrand=4
# 362  version_529  cifar20      CPE             F      llava_kmean=20_nrand=4
# 377   version_56  cifar20      CPE             F                   as_setup1
# 379   version_58  cifar20      CPE             F                   as_setup3
# 380   version_59  cifar20      CPE             F                   as_setup2
# 387   version_67  cifar20      CPE             F                   as_setup4
# 394   version_73  cifar20      CPE             F                   as_setup4
# 407   version_91  cifar20      CPE             T                   as_setup3
# 408   version_92  cifar20      CPE             T                   as_setup3
# 409   version_93  cifar20      CPE             T                   as_setup3
# 410   version_97  cifar20      CPE             T                     uniform
# 411   version_98  cifar20      CPE             T                     uniform
#
#      best_test_acc  seed     model   augment
# 1        18.991843  2202  ResNet18      None
# 9         5.020681    42  ResNet18      None
# 56       46.047220    42  ResNet18      None
# 57       47.039866  1126  ResNet18      None
# 58       46.171305  2202  ResNet18      None
# 59       38.550669    42  ResNet18      None
# 60       37.933135  1126  ResNet18      None
# 61       38.133043  2202  ResNet18      None
# 62       44.553080    42  ResNet18      None
# 63       45.696807  1126  ResNet18      None
# 64       45.694509  2202  ResNet18      None
# 79        0.144210  1126  ResNet18      None
# 83        0.133789    42  ResNet18      None
# 94        0.160283  2202  ResNet18      None
# 105       0.220985  2202  ResNet18      None
# 116       0.207301  1126  ResNet18      None
# 125       0.201011    42  ResNet18      None
# 148      45.608917    42  ResNet34      None
# 149      46.092603  1126  ResNet34      None
# 151      44.370404  2202  ResNet34      None
# 152      39.729437    42  ResNet34      None
# 153      41.548714  1126  ResNet34      None
# 154      39.600760  2202  ResNet34      None
# 155      44.274473    42  ResNet34      None
# 156      45.174631  1126  ResNet34      None
# 157      45.774934  2202  ResNet34      None
# 290      67.576975    42  ResNet18  flipflop
# 292      67.444855    42  ResNet18  flipflop
# 295      67.860180    42  ResNet18  flipflop
# 303      65.042514    42  ResNet18  flipflop
# 307      67.197841    42  ResNet18  flipflop
# 309      63.775277    42  ResNet18  flipflop
# 317      65.413028    42  ResNet18  flipflop
# 320      63.825256    42  ResNet18  flipflop
# 322      62.530446    42  ResNet18  flipflop
# 348      18.943588    42  ResNet50  flipflop
# 349      16.209789  1126  ResNet50  flipflop
# 350      18.667279  2202  ResNet50  flipflop
# 359      43.266317    42  ResNet50  flipflop
# 361      44.644418  1126  ResNet50  flipflop
# 362      45.652571  2202  ResNet50  flipflop
# 377       0.618986    42  ResNet18      None
# 379       0.675626    42  ResNet18      None
# 380       0.669118    42  ResNet18      None
# 387       0.709203    42  ResNet18      None
# 394       0.707071    42  ResNet18      None
# 407      64.743227    42  ResNet18      None
# 408      69.536418  1126  ResNet18      None
# 409      68.139362  2202  ResNet18      None
# 410      19.280790    42  ResNet18      None
# 411      16.579159  1126  ResNet18      None
# == ('cifar20', 'FWD') (31 rows) ==
#          version  dataset strategy strategy_type           transition_matrix  \
# 15   version_133  cifar20      FWD            NL      llava_kmean=20_nrand=4
# 16   version_134  cifar20      FWD            NL      llava_kmean=20_nrand=4
# 17   version_135  cifar20      FWD            NL      llava_kmean=20_nrand=4
# 120  version_243  cifar20      FWD            NL      llava_kmean=20_nrand=4
# 121  version_244  cifar20      FWD            NL      llava_kmean=20_nrand=4
# 122  version_245  cifar20      FWD            NL      llava_kmean=20_nrand=4
# 237  version_376  cifar20      FWD           TGA                     uniform
# 260  version_399  cifar20      FWD            NL   llava_noise=False-nrand=2
# 261    version_4  cifar20      FWD            NL                     uniform
# 262  version_400  cifar20      FWD            NL   llava_noise=False-nrand=3
# 263  version_401  cifar20      FWD            NL   llava_noise=False-nrand=4
# 267  version_405  cifar20      FWD            NL   llava_noise=False-nrand=5
# 268  version_406  cifar20      FWD            NL   llava_noise=False-nrand=6
# 269  version_407  cifar20      FWD            NL   llava_noise=False-nrand=7
# 272  version_410  cifar20      FWD            NL   llava_noise=False-nrand=8
# 273  version_411  cifar20      FWD            NL   llava_noise=False-nrand=9
# 282  version_422  cifar20      FWD            NL  llava_noise=False-nrand=10
# 337    version_5  cifar20      FWD            NL                     uniform
# 338   version_50  cifar20      FWD            NL                   as_setup1
# 345  version_513  cifar20      FWD            NL                     uniform
# 346  version_514  cifar20      FWD            NL                     uniform
# 347  version_515  cifar20      FWD            NL                     uniform
# 355  version_522  cifar20      FWD            NL      llava_kmean=20_nrand=4
# 356  version_523  cifar20      FWD            NL      llava_kmean=20_nrand=4
# 357  version_524  cifar20      FWD            NL      llava_kmean=20_nrand=4
# 358  version_525  cifar20      FWD            NL      llava_kmean=20_nrand=4
# 363   version_53  cifar20      FWD            NL                   as_setup2
# 374   version_54  cifar20      FWD            NL                   as_setup3
# 381    version_6  cifar20      FWD            NL                     uniform
# 386   version_66  cifar20      FWD             F                   as_setup4
# 395   version_74  cifar20      FWD             F                   as_setup4
#
#      best_test_acc  seed     model   augment
# 15       47.306988    42  ResNet18      None
# 16       47.989431  1126  ResNet18      None
# 17       47.752759  2202  ResNet18      None
# 120      46.350527    42  ResNet34      None
# 121      47.280559  1126  ResNet34      None
# 122      45.974836  2202  ResNet34      None
# 237      19.351448    42  ResNet34  flipflop
# 260      67.618340    42  ResNet18  flipflop
# 261       0.199764    42  ResNet18      None
# 262      67.817670    42  ResNet18  flipflop
# 263      67.878562    42  ResNet18  flipflop
# 267      66.128218    42  ResNet18  flipflop
# 268      67.591912    42  ResNet18  flipflop
# 269      65.024132    42  ResNet18  flipflop
# 272      66.877300    42  ResNet18  flipflop
# 273      64.190602    42  ResNet18  flipflop
# 282      63.013560    42  ResNet18  flipflop
# 337       0.218313  2202  ResNet18      None
# 338       0.615091    42  ResNet18      None
# 345      18.907399    42  ResNet50  flipflop
# 346      16.293658  1126  ResNet50  flipflop
# 347      18.785617  2202  ResNet50  flipflop
# 355      44.584677    42  ResNet50  flipflop
# 356      44.584677    42  ResNet50  flipflop
# 357      45.929462  1126  ResNet50  flipflop
# 358      46.513101  2202  ResNet50  flipflop
# 363       0.671232    42  ResNet18      None
# 374       0.676103    42  ResNet18      None
# 381       0.207657  1126  ResNet18      None
# 386       0.708812    42  ResNet18      None
# 395       0.706486    42  ResNet18      None
# == ('cifar20', 'URE') (17 rows) ==
#          version  dataset strategy strategy_type       transition_matrix  \
# 18   version_136  cifar20      URE           TNN  llava_kmean=20_nrand=4
# 19   version_137  cifar20      URE           TNN  llava_kmean=20_nrand=4
# 21   version_139  cifar20      URE           TNN  llava_kmean=20_nrand=4
# 24   version_141  cifar20      URE           TGA  llava_kmean=20_nrand=4
# 26   version_143  cifar20      URE           TGA  llava_kmean=20_nrand=4
# 27   version_144  cifar20      URE           TGA  llava_kmean=20_nrand=4
# 123  version_246  cifar20      URE           TNN  llava_kmean=20_nrand=4
# 124  version_248  cifar20      URE           TNN  llava_kmean=20_nrand=4
# 126  version_250  cifar20      URE           TNN  llava_kmean=20_nrand=4
# 127  version_252  cifar20      URE           TGA  llava_kmean=20_nrand=4
# 128  version_254  cifar20      URE           TGA  llava_kmean=20_nrand=4
# 129  version_256  cifar20      URE           TGA  llava_kmean=20_nrand=4
# 183   version_32  cifar20      URE           TNN                 uniform
# 194   version_33  cifar20      URE           TNN                 uniform
# 390    version_7  cifar20      URE           TGA                 uniform
# 399    version_8  cifar20      URE           TGA                 uniform
# 405    version_9  cifar20      URE           TGA                 uniform
#
#      best_test_acc  seed     model augment
# 18       19.034353    42  ResNet18    None
# 19       17.274241  1126  ResNet18    None
# 21       15.683019  2202  ResNet18    None
# 24        5.046530    42  ResNet18    None
# 26        5.046530  1126  ResNet18    None
# 27        5.046530  2202  ResNet18    None
# 123      18.885569    42  ResNet34    None
# 124      18.243337  1126  ResNet34    None
# 126      16.357422  2202  ResNet34    None
# 127       5.046530    42  ResNet34    None
# 128       5.046530  1126  ResNet34    None
# 129       5.046530  2202  ResNet34    None
# 183       0.146145  1126  ResNet18    None
# 194       0.156962    42  ResNet18    None
# 390       0.155997    42  ResNet18    None
# 399       0.161202  1126  ResNet18    None
# 405       0.166033  2202  ResNet18    None
# == ('clcifar10', 'FWD') (1 rows) ==
#          version    dataset strategy strategy_type transition_matrix  \
# 239  version_378  clcifar10      FWD           TGA           uniform
#
#      best_test_acc  seed     model   augment
# 239      40.186697    42  ResNet34  flipflop
# == ('clcifar20', 'FWD') (1 rows) ==
#          version    dataset strategy strategy_type transition_matrix  \
# 238  version_377  clcifar20      FWD           TGA           uniform
#
#      best_test_acc  seed     model   augment
# 238      20.966223    42  ResNet34  flipflop
# == ('tiny200', 'CE') (3 rows) ==
#          version  dataset strategy strategy_type transition_matrix  \
# 234  version_373  tiny200       CE            NL        llava_true
# 235  version_374  tiny200       CE            NL        llava_true
# 236  version_375  tiny200       CE            NL        llava_true
#
#      best_test_acc  seed     model   augment
# 234      16.507928    42  ResNet34  flipflop
# 235      16.287914  1126  ResNet34  flipflop
# 236      16.835938  2202  ResNet34  flipflop
# == ('tiny200', 'CPE') (64 rows) ==
#          version  dataset strategy strategy_type           transition_matrix  \
# 4    version_103  tiny200      CPE             I                     uniform
# 5    version_104  tiny200      CPE             I                     uniform
# 6    version_105  tiny200      CPE             I                     uniform
# 10   version_115  tiny200      CPE             I                     uniform
# 11   version_116  tiny200      CPE             I                     uniform
# 12   version_117  tiny200      CPE             I                     uniform
# 75   version_188  tiny200      CPE             T                     uniform
# 76   version_189  tiny200      CPE             T                     uniform
# 77    version_19  tiny200      CPE             F                     uniform
# 78   version_190  tiny200      CPE             T                     uniform
# 84   version_210  tiny200      CPE             F     llava_kmean=200_nrand=4
# 85   version_211  tiny200      CPE             F     llava_kmean=200_nrand=4
# 86   version_212  tiny200      CPE             F     llava_kmean=200_nrand=4
# 90   version_216  tiny200      CPE             I     llava_kmean=200_nrand=4
# 91   version_217  tiny200      CPE             I     llava_kmean=200_nrand=4
# 92   version_218  tiny200      CPE             I     llava_kmean=200_nrand=4
# 97   version_222  tiny200      CPE             T     llava_kmean=200_nrand=4
# 98   version_223  tiny200      CPE             T     llava_kmean=200_nrand=4
# 99   version_224  tiny200      CPE             T     llava_kmean=200_nrand=4
# 145  version_285  tiny200      CPE             F     llava_kmean=200_nrand=4
# 146  version_286  tiny200      CPE             F     llava_kmean=200_nrand=4
# 147  version_287  tiny200      CPE             F     llava_kmean=200_nrand=4
# 171  version_309  tiny200      CPE             I     llava_kmean=200_nrand=4
# 173  version_310  tiny200      CPE             I     llava_kmean=200_nrand=4
# 174  version_311  tiny200      CPE             I     llava_kmean=200_nrand=4
# 178  version_315  tiny200      CPE             T     llava_kmean=200_nrand=4
# 179  version_316  tiny200      CPE             T     llava_kmean=200_nrand=4
# 180  version_317  tiny200      CPE             T     llava_kmean=200_nrand=4
# 181  version_318  tiny200      CPE             F     llava_kmean=200_nrand=4
# 182  version_319  tiny200      CPE             F     llava_kmean=200_nrand=4
# 184  version_320  tiny200      CPE             F     llava_kmean=200_nrand=4
# 210  version_345  tiny200      CPE             I     llava_kmean=200_nrand=4
# 211  version_346  tiny200      CPE             I     llava_kmean=200_nrand=4
# 212  version_347  tiny200      CPE             I     llava_kmean=200_nrand=4
# 213  version_348  tiny200      CPE             T     llava_kmean=200_nrand=4
# 214  version_349  tiny200      CPE             T     llava_kmean=200_nrand=4
# 215  version_350  tiny200      CPE             T     llava_kmean=200_nrand=4
# 230  version_369  tiny200      CPE             F                     uniform
# 232  version_371  tiny200      CPE             F                     uniform
# 233  version_372  tiny200      CPE             F                     uniform
# 246  version_385  tiny200      CPE             I                     uniform
# 247  version_386  tiny200      CPE             I                     uniform
# 248  version_387  tiny200      CPE             I                     uniform
# 252  version_391  tiny200      CPE             T                     uniform
# 253  version_392  tiny200      CPE             T                     uniform
# 254  version_393  tiny200      CPE             T                     uniform
# 313  version_458  tiny200      CPE             F   llava_noise=False-nrand=2
# 314  version_459  tiny200      CPE             F   llava_noise=False-nrand=3
# 316  version_460  tiny200      CPE             F   llava_noise=False-nrand=4
# 327  version_470  tiny200      CPE             F   llava_noise=False-nrand=5
# 328  version_471  tiny200      CPE             F   llava_noise=False-nrand=6
# 329  version_472  tiny200      CPE             F   llava_noise=False-nrand=7
# 330  version_473  tiny200      CPE             F   llava_noise=False-nrand=8
# 331  version_474  tiny200      CPE             F   llava_noise=False-nrand=9
# 332  version_475  tiny200      CPE             F  llava_noise=False-nrand=10
# 334  version_494  tiny200      CPE             F                     uniform
# 335  version_495  tiny200      CPE             F                     uniform
# 336  version_497  tiny200      CPE             F                     uniform
# 351  version_519  tiny200      CPE             F     llava_kmean=200_nrand=4
# 353  version_520  tiny200      CPE             F     llava_kmean=200_nrand=4
# 354  version_521  tiny200      CPE             F     llava_kmean=200_nrand=4
# 396   version_75  tiny200      CPE             F                     uniform
# 397   version_76  tiny200      CPE             F                     uniform
# 398   version_77  tiny200      CPE             F                     uniform
#
#      best_test_acc  seed     model   augment
# 4         1.903722  1126  ResNet18      None
# 5         1.538373  2202  ResNet18      None
# 6         1.566521    42  ResNet18      None
# 10        1.566521    42  ResNet18      None
# 11        1.903722  1126  ResNet18      None
# 12        1.538373  2202  ResNet18      None
# 75        1.119600  1126  ResNet18      None
# 76        1.208640    42  ResNet18      None
# 77        0.024862    42  ResNet18      None
# 78        1.234490  2202  ResNet18      None
# 84       29.948875    42  ResNet18      None
# 85       30.719784  1126  ResNet18      None
# 86       30.434856  2202  ResNet18      None
# 90       21.083985    42  ResNet18      None
# 91       20.080423  1126  ResNet18      None
# 92       20.503794  2202  ResNet18      None
# 97       29.122242    42  ResNet18      None
# 98       29.654756  1126  ResNet18      None
# 99       29.682904  2202  ResNet18      None
# 145      30.255631    42  ResNet34      None
# 146      31.040904  1126  ResNet34      None
# 147      27.705655  2202  ResNet34      None
# 171      21.330999    42  ResNet34      None
# 173      21.645795  1126  ResNet34      None
# 174      22.134076  2202  ResNet34      None
# 178      29.576632    42  ResNet34      None
# 179      29.030904  1126  ResNet34      None
# 180      26.931295  2202  ResNet34      None
# 181      26.818129  2202  ResNet34      None
# 182      29.559398  1126  ResNet34      None
# 184      30.308482    42  ResNet34      None
# 210      22.309856    42  ResNet34      None
# 211      21.764131  1126  ResNet34      None
# 212      22.150736  2202  ResNet34      None
# 213      27.232310  1126  ResNet34      None
# 214      29.312959    42  ResNet34      None
# 215      26.697496  2202  ResNet34      None
# 230       1.916935    42  ResNet34  flipflop
# 232       2.520106  1126  ResNet34  flipflop
# 233       1.545841  2202  ResNet34  flipflop
# 246       1.260340    42  ResNet34  flipflop
# 247       1.549288  1126  ResNet34  flipflop
# 248       1.536075  2202  ResNet34  flipflop
# 252       1.309168    42  ResNet34  flipflop
# 253       0.855928  1126  ResNet34  flipflop
# 254       1.239660  2202  ResNet34  flipflop
# 313      46.000692    42  ResNet18  flipflop
# 314      46.487823    42  ResNet18  flipflop
# 316      47.105357    42  ResNet18  flipflop
# 327      46.776772    42  ResNet18  flipflop
# 328      46.507356    42  ResNet18  flipflop
# 329      46.220705    42  ResNet18  flipflop
# 330      45.833525    42  ResNet18  flipflop
# 331      44.884539    42  ResNet18  flipflop
# 332      45.569855    42  ResNet18  flipflop
# 334       2.412684    42  ResNet50  flipflop
# 335       2.159926  1126  ResNet50  flipflop
# 336       1.332146  2202  ResNet50  flipflop
# 351      30.299288    42  ResNet50  flipflop
# 353      30.037341  1126  ResNet50  flipflop
# 354      28.893039  2202  ResNet50  flipflop
# 396       1.931871  1126  ResNet18      None
# 397       2.373621    42  ResNet18      None
# 398       2.361558  2202  ResNet18      None
# == ('tiny200', 'FWD') (24 rows) ==
#          version  dataset strategy strategy_type           transition_matrix  \
# 80   version_207  tiny200      FWD            NL     llava_kmean=200_nrand=4
# 81   version_208  tiny200      FWD            NL     llava_kmean=200_nrand=4
# 82   version_209  tiny200      FWD            NL     llava_kmean=200_nrand=4
# 131  version_264  tiny200      FWD            NL     llava_kmean=200_nrand=4
# 132  version_265  tiny200      FWD            NL     llava_kmean=200_nrand=4
# 133  version_266  tiny200      FWD            NL     llava_kmean=200_nrand=4
# 185  version_321  tiny200      FWD            NL                     uniform
# 186  version_322  tiny200      FWD            NL                     uniform
# 187  version_323  tiny200      FWD            NL                     uniform
# 228  version_367  tiny200      FWD            NL                     uniform
# 229  version_368  tiny200      FWD            NL                     uniform
# 231  version_370  tiny200      FWD            NL                     uniform
# 284  version_424  tiny200      FWD            NL   llava_noise=False-nrand=2
# 285  version_425  tiny200      FWD            NL   llava_noise=False-nrand=4
# 287  version_427  tiny200      FWD            NL   llava_noise=False-nrand=3
# 297  version_443  tiny200      FWD            NL   llava_noise=False-nrand=5
# 298  version_444  tiny200      FWD            NL   llava_noise=False-nrand=6
# 299  version_445  tiny200      FWD            NL   llava_noise=False-nrand=7
# 304   version_45  tiny200      FWD            NL                     uniform
# 315   version_46  tiny200      FWD            NL                     uniform
# 323  version_467  tiny200      FWD            NL   llava_noise=False-nrand=8
# 324  version_468  tiny200      FWD            NL   llava_noise=False-nrand=9
# 325  version_469  tiny200      FWD            NL  llava_noise=False-nrand=10
# 326   version_47  tiny200      FWD            NL                     uniform
#
#      best_test_acc  seed     model   augment
# 80       30.973116  2202  ResNet18      None
# 81       30.918545    42  ResNet18      None
# 82       31.511948  1126  ResNet18      None
# 131      31.025392    42  ResNet34      None
# 132      31.528035  1126  ResNet34      None
# 133      28.357077  2202  ResNet34      None
# 185       1.907169    42  ResNet34      None
# 186       2.792394  1126  ResNet34      None
# 187       1.671645  2202  ResNet34      None
# 228       1.907169    42  ResNet34  flipflop
# 229       2.792394  1126  ResNet34  flipflop
# 231       1.671645  2202  ResNet34  flipflop
# 284      46.089730    42  ResNet18  flipflop
# 285      47.193247    42  ResNet18  flipflop
# 287      46.663603    42  ResNet18  flipflop
# 297      46.880171    42  ResNet18  flipflop
# 298      46.685433    42  ResNet18  flipflop
# 299      46.323529    42  ResNet18  flipflop
# 304       0.023076    42  ResNet18      None
# 315       0.023909  2202  ResNet18      None
# 323      45.890972    42  ResNet18  flipflop
# 324      44.931069    42  ResNet18  flipflop
# 325      45.883504    42  ResNet18  flipflop
# 326       0.020295  1126  ResNet18      None
# == ('tiny200', 'URE') (29 rows) ==
#          version  dataset strategy strategy_type        transition_matrix  \
# 87   version_213  tiny200      URE           TNN  llava_kmean=200_nrand=4
# 88   version_214  tiny200      URE           TNN  llava_kmean=200_nrand=4
# 89   version_215  tiny200      URE           TNN  llava_kmean=200_nrand=4
# 93   version_219  tiny200      URE           TGA  llava_kmean=200_nrand=4
# 95   version_220  tiny200      URE           TGA  llava_kmean=200_nrand=4
# 96   version_221  tiny200      URE           TGA  llava_kmean=200_nrand=4
# 168  version_306  tiny200      URE           TNN  llava_kmean=200_nrand=4
# 169  version_307  tiny200      URE           TNN  llava_kmean=200_nrand=4
# 170  version_308  tiny200      URE           TNN  llava_kmean=200_nrand=4
# 175  version_312  tiny200      URE           TGA  llava_kmean=200_nrand=4
# 176  version_313  tiny200      URE           TGA  llava_kmean=200_nrand=4
# 177  version_314  tiny200      URE           TGA  llava_kmean=200_nrand=4
# 207  version_342  tiny200      URE           TNN                  uniform
# 208  version_343  tiny200      URE           TNN                  uniform
# 209  version_344  tiny200      URE           TNN                  uniform
# 216  version_351  tiny200      URE           TGA                  uniform
# 217  version_352  tiny200      URE           TGA                  uniform
# 218  version_353  tiny200      URE           TGA                  uniform
# 243  version_382  tiny200      URE           TNN                  uniform
# 244  version_383  tiny200      URE           TNN                  uniform
# 245  version_384  tiny200      URE           TNN                  uniform
# 249  version_388  tiny200      URE           TGA                  uniform
# 250  version_389  tiny200      URE           TGA                  uniform
# 251  version_390  tiny200      URE           TGA                  uniform
# 388   version_68  tiny200      URE           TNN                  uniform
# 389   version_69  tiny200      URE           TNN                  uniform
# 391   version_70  tiny200      URE           TNN                  uniform
# 392   version_71  tiny200      URE           TGA                  uniform
# 393   version_72  tiny200      URE           TGA                  uniform
#
#      best_test_acc  seed     model   augment
# 87        6.972656    42  ResNet18      None
# 88        7.579848  2202  ResNet18      None
# 89        7.273093  1126  ResNet18      None
# 93        0.488281    42  ResNet18      None
# 95        0.488281  1126  ResNet18      None
# 96        0.488281  2202  ResNet18      None
# 168       5.396944    42  ResNet34      None
# 169       5.738741  1126  ResNet34      None
# 170       6.369486  2202  ResNet34      None
# 175       0.488281    42  ResNet34      None
# 176       0.488281  1126  ResNet34      None
# 177       0.488281  2202  ResNet34      None
# 207       0.535960    42  ResNet34      None
# 208       0.605469  1126  ResNet34      None
# 209       0.593405  2202  ResNet34      None
# 216       0.556641    42  ResNet34      None
# 217       0.603171  1126  ResNet34      None
# 218       0.573874  2202  ResNet34      None
# 243       0.605469  1126  ResNet34  flipflop
# 244       0.535960    42  ResNet34  flipflop
# 245       0.593405  2202  ResNet34  flipflop
# 249       0.556641    42  ResNet34  flipflop
# 250       0.603171  1126  ResNet34  flipflop
# 251       0.573874  2202  ResNet34  flipflop
# 388       0.005543    42  ResNet18      None
# 389       0.005923  1126  ResNet18      None
# 391       0.006531  2202  ResNet18      None
# 392       0.005067  1126  ResNet18      None
# 393       0.005566  2202  ResNet18      None
